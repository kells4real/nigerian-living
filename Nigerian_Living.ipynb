# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv("datas/nigeria-access-to-electricity.csv")

# %%
df2 = pd.read_csv("datas/nigeria-households-possessing-auto.csv")

# %%
df3 = pd.read_csv("datas/nigeria-refrigerator-ownership.csv")

# %%
df1.head()
# Out:
#        Geography  Access to electricity  No electricity
# 0        Nigeria                   59.4            40.6
# 1          Urban                   82.7            17.3
# 2          Rural                   38.9            61.1
# 3  North Central                   56.8            43.2
# 4     North East                   36.1            63.9

# %%
df2.head()
# Out:
#         Geography  Households possessing a bicycle  \
# 0         Nigeria                             12.5
# 1           Urban                              9.4
# 2           Rural                             15.2
# 3   North Central                              6.2
# 4      North East                             20.4
#
#    Households possessing an animal drawn cart  \
# 0                                         3.1
# 1                                         0.7
# 2                                         5.2
# 3                                         0.8
# 4                                         8.2
#
#    Households possessing a motorcycle  Households possessing a private car  \
# 0                                27.5                                  9.3
# 1                                21.3                                 13.9
# 2                                32.9                                  5.2
# ...

# %%
df3.head()
# Out:
#        Geography  Households possessing a refrigerator
# 0        Nigeria                                  22.0
# 1          Urban                                  35.3
# 2          Rural                                  10.3
# 3  North Central                                  18.4
# 4     North East                                   9.3

# %%
new_data = pd.merge(df1, df3)

# %%
new_data.head()
# Out:
#        Geography  Access to electricity  No electricity  \
# 0        Nigeria                   59.4            40.6
# 1          Urban                   82.7            17.3
# 2          Rural                   38.9            61.1
# 3  North Central                   56.8            43.2
# 4     North East                   36.1            63.9
#
#    Households possessing a refrigerator
# 0                                  22.0
# 1                                  35.3
# 2                                  10.3
# 3                                  18.4
# 4                                   9.3

# %%
new_data.tail()
# Out:
#       Geography  Access to electricity  No electricity  \
# 41      Bayelsa                   47.1            52.9
# 42  Cross River                   53.5            46.5
# 43        Delta                   72.0            28.0
# 44          Edo                   70.1            29.9
# 45       Rivers                   81.9            18.1
#
#     Households possessing a refrigerator
# 41                                  26.6
# 42                                  21.6
# 43                                  31.9
# 44                                  32.7
# 45                                  42.4

# %%
new_data["Households with a private car"] = [i for i in df2['Households possessing a private car']]

# %%
new_data["Households with a motocycle"] = [i for i in df2['Households possessing a motorcycle']]

# %%
new_data.head()
# Out:
#        Geography  Access to electricity  No electricity  \
# 0        Nigeria                   59.4            40.6
# 1          Urban                   82.7            17.3
# 2          Rural                   38.9            61.1
# 3  North Central                   56.8            43.2
# 4     North East                   36.1            63.9
#
#    Households possessing a refrigerator  Households with a private car  \
# 0                                  22.0                            9.3
# 1                                  35.3                           13.9
# 2                                  10.3                            5.2
# 3                                  18.4                           10.0
# 4                                   9.3                            6.7
#
#    Households with a motocycle
# 0                         27.5
# 1                         21.3
# 2                         32.9
# 3                         42.0
# 4                         21.2

# %%
plt.style.use('_mpl-gallery')
